# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
ha = pd.read_csv('HR-Employee-Attrition.csv')
ha.shape
# Out:
# (1470, 35)

# %%
ha.sample(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 61     38        No  Travel_Frequently        653  Research & Development
# 747    38        No      Travel_Rarely       1035                   Sales
# 375    49        No      Travel_Rarely       1261  Research & Development
# 650    43        No  Travel_Frequently        422  Research & Development
# 1260   32        No         Non-Travel        953  Research & Development
# 668    28        No      Travel_Rarely        995  Research & Development
# 788    28        No      Travel_Rarely        857  Research & Development
# 1051   44        No  Travel_Frequently        383                   Sales
# 282    29        No  Travel_Frequently        442                   Sales
# 289    28        No      Travel_Rarely       1117  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 61                  29          5     Life Sciences              1
# 747                  3          4     Life Sciences              1
# 375                  7          3             Other              1
# 650                  1          3     Life Sciences              1
# 1260                 5          4  Technical Degree              1
# 668                  9          3           Medical              1
# 788                 10          3             Other              1
# 1051                 1          5         Marketing              1
# 282                  2          2     Life Sciences              1
# 289                  8          2     Life Sciences              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 61                79                        4  Female          50
# 747             1036                        2    Male          42
# 375              499                        2    Male          31
# 650              902                        4  Female          33
# 1260            1764                        2    Male          65
# 668              930                        3  Female          77
# 788             1097                        3  Female          59
# 1051            1481                        1  Female          79
# 282              388                        2    Male          44
# 289              395                        4  Female          66
#
#       JobInvolvement  JobLevel                    JobRole  JobSatisfaction  \
# 61                 3         2      Laboratory Technician                4
# 747                3         2            Sales Executive                4
# 375                2         3  Healthcare Representative                3
# 650                3         2  Healthcare Representative                4
# 1260               3         1         Research Scientist                2
# 668                3         1         Research Scientist                3
# 788                3         2         Research Scientist                3
# 1051               3         2            Sales Executive                3
# 282                3         2            Sales Executive                4
# 289                3         1         Research Scientist                4
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 61          Single           2406         5456                   1      Y
# 747         Single           6861         4981                   8      Y
# 375         Single          10965        12066                   8      Y
# 650        Married           5562        21782                   4      Y
# 1260        Single           2718        17674                   2      Y
# 668       Divorced           2377         9834                   5      Y
# 788         Single           3660         7909                   3      Y
# 1051       Married           4768         9282                   7      Y
# 282         Single           4554        20260                   1      Y
# 289         Single           3310         4488                   1      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 61         No                 11                  3                         4
# 747       Yes                 12                  3                         3
# 375        No                 24                  4                         3
# 650        No                 13                  3                         2
# 1260       No                 14                  3                         2
# 668        No                 18                  3                         2
# 788        No                 13                  3                         4
# 1051       No                 12                  3                         3
# 282        No                 18                  3                         1
# 289        No                 21                  4                         4
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 61               80                 0                 10
# 747              80                 0                 19
# 375              80                 0                 26
# 650              80                 1                 12
# 1260             80                 0                 12
# 668              80                 1                  6
# 788              80                 0                 10
# 1051             80                 1                 11
# 282              80                 0                 10
# 289              80                 0                  5
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 61                        2                3              10
# 747                       1                3               1
# 375                       2                3               5
# 650                       2                2               5
# 1260                      3                3               7
# 668                       2                3               2
# 788                       4                4               8
# 1051                      4                2               1
# 282                       3                2              10
# 289                       3                3               5
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 61                     3                        9                     9
# 747                    0                        0                     0
# 375                    2                        0                     0
# 650                    2                        2                     2
# 1260                   7                        0                     7
# 668                    2                        2                     2
# 788                    7                        1                     7
# 1051                   0                        0                     0
# 282                    7                        0                     9
# 289                    3                        0                     2

# %%
ha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
ha.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike         1470.0     15.209524     3.659938    11.0    12.00
# PerformanceRating         1470.0      3.153741     0.360824     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.00
# StandardHours             1470.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.00
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.00
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.00
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.00
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.00
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='magma')
plt.title('Correlation Heatmap', fontsize=30)
plt.show()

# %%
categorical_cols = [feature for feature in df.columns if df[feature].dtypes=='object']
df[categorical_cols].sample(5)
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 1420        No      Travel_Rarely  Research & Development  Life Sciences
# 620         No      Travel_Rarely  Research & Development        Medical
# 870         No      Travel_Rarely                   Sales  Life Sciences
# 427         No  Travel_Frequently                   Sales      Marketing
# 1095        No      Travel_Rarely  Research & Development  Life Sciences
#
#       Gender                JobRole MaritalStatus Over18 OverTime
# 1420    Male     Research Scientist       Married      Y       No
# 620   Female     Research Scientist        Single      Y       No
# 870     Male        Sales Executive       Married      Y      Yes
# 427   Female        Sales Executive       Married      Y       No
# 1095    Male  Laboratory Technician       Married      Y      Yes

# %%
numerical_cols = [feature for feature in df.columns if df[feature].dtypes!='object']
df[numerical_cols].sample(5)
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 641    32        379                 5          2              1
# 1344   37        783                 7          4              1
# 208    40       1151                 9          5              1
# 506    37        482                 3          3              1
# 1253   33       1283                 2          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 641              889                        2          48               3
# 1344            1885                        4          78               3
# 208              287                        4          63               2
# 506              689                        3          36               3
# 1253            1756                        4          62               3
#
#       JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# 641          2                2           6524         8891
# 1344         2                1           4284        13588
# 208          2                4           4876        14242
# 506          3                3           9434         9606
# 1253         2                2           5147        10697
#
#       NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# 641                    1                 14                  3
# 1344                   5                 22                  4
# 208                    9                 14                  3
# 506                    1                 15                  3
# 1253                   8                 15                  3
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 641                          4             80                 1
# 1344                         3             80                 1
# 208                          4             80                 1
# 506                          3             80                 1
# 1253                         4             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 641                  10                      3                3
# 1344                 16                      2                3
# 208                   5                      5                1
# 506                  10                      2                3
# 1253                 13                      2                2
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 641               10                   8                        5
# 1344               5                   3                        0
# 208                3                   2                        0
# 506               10                   7                        7
# 1253              11                   7                        1
#
#       YearsWithCurrManager
# 641                      3
# 1344                     4
# 208                      2
# 506                      8
# 1253                     7

# %%
size = df['BusinessTravel'].value_counts()
labels = df['BusinessTravel'].unique()
colors = plt.cm.Wistia(np.linspace(0,1,5))

plt.figure(figsize=(10,10))
circle =plt.Circle((0,0), radius=0.7, color='white')
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Percentage of BusinessTravel of Employess', fontsize=30)
plt.legend(bbox_to_anchor=(0.5,0.,0.9,0.9));

# %%
size = df['Department'].value_counts()
labels = df['Department'].unique()
colors = plt.cm.Wistia(np.linspace(0,1,5))

plt.figure(figsize=(10,10))
circle =plt.Circle((0,0), radius=0.7, color='white')
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Percentage of Employess in Department', fontsize=30)
plt.legend(bbox_to_anchor=(0.5,0.,0.9,0.9));

# %%
size = df['EducationField'].value_counts()
labels = df['EducationField'].unique()
colors = plt.cm.Wistia(np.linspace(0,1,5))

plt.figure(figsize=(10,10))
circle =plt.Circle((0,0), radius=0.7, color='white')
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Percentage of Education Filed', fontsize=30)
plt.legend(bbox_to_anchor=(0.5,0.,0.9,0.9));

# %%
size = df['JobRole'].value_counts()
labels = df['JobRole'].unique()
colors = plt.cm.Wistia(np.linspace(0,1,5))

plt.figure(figsize=(10,10))
circle =plt.Circle((0,0), radius=0.7, color='white')
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Percentage of Employees Job Role', fontsize=30)
plt.legend(bbox_to_anchor=(0.5,0.,0.9,0.9));

# %%
size = df['MaritalStatus'].value_counts()
labels = df['MaritalStatus'].unique()
colors = plt.cm.Wistia(np.linspace(0,1,5))
explode = [0.03, 0.03, 0.03]

plt.figure(figsize=(10,10))
plt.pie(size, colors = colors, labels = labels, explode = explode , autopct = '%.2f%%' , shadow = True)
plt.title('Count Gender of Employess', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Age'], bins =30, hist_kws=dict(edgecolor='black',linewidth=2))
plt.title('Age of Employees', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(19,6))
x = df[['Age', 'DailyRate']].groupby('Age').mean()
x = pd.DataFrame(x)
x.sort_values(by = 'Age').plot(kind='bar', figsize=(19,6));

# %%
data=pd.crosstab(df['BusinessTravel'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Business Travel in determining Attrition', fontsize=30)
plt.xlabel('Business Travel')
plt.show()

# %%
data=pd.crosstab(df['Department'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Department in determining Attrition', fontsize=30)
plt.xlabel('Department')
plt.show()

# %%
data=pd.crosstab(df['JobRole'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Job Role in Attrition', fontsize=30)
plt.xlabel('JobRole')
plt.show()

# %%
data=pd.crosstab(df['OverTime'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Over Time determining Attrition', fontsize=30)
plt.xlabel('OverTime')
plt.show()

# %%
data=pd.crosstab(df['RelationshipSatisfaction'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Relationship Satisfaction Determining Attrition', fontsize=30)
plt.xlabel('RelationshipSatisfaction')
plt.show()

# %%
data=pd.crosstab(df['YearsAtCompany'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Years At Company Determining Attrition', fontsize=30)
plt.xlabel('YearsAtcompany')
plt.show()

# %%
data=pd.crosstab(df['YearsInCurrentRole'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Years In Current Role Determining Attrition', fontsize=30)
plt.xlabel('YearsInCurrentRole')
plt.show()

# %%
data=pd.crosstab(df['YearsSinceLastPromotion'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(12,6))
plt.title('Dependency of Years Since Last Promotion Determining Attrition', fontsize=30)
plt.xlabel('YearsSinceLastPromotion')
plt.show()

# %%
data=pd.crosstab(df['YearsWithCurrManager'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, color=['brown', 'cyan'], 
                                                figsize=(17,6))
plt.title('Dependency of Years With Curr Manager Determining Attrition', fontsize=30)
plt.xlabel('YearsWithCurrManager')
plt.show()
